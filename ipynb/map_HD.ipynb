# %%
import pandas as pd
import numpy as np

# %%
import folium
map = folium.Map(location=[36,127],zoom_start=7)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78be8411377028d33fb7ac6bc8b08372 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78be8411377028d33fb7ac6bc8b08372&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78be8411377028d33fb7ac6bc8b08372 = L.map(
#                 &quot;map_78be8411377028d33fb7ac6bc8b08372&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cd1bb70fb9658842d611d96c2f91b89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cd1bb70fb9658842d611d96c2f91b89.addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
HD = pd.read_csv('현대글로비스_위도경도.csv')
HD
# Out:
#    상호명       사업자번호                                         소재지  일반창고면적(m²)  \
# 0    A  1068197118                     경기도 용인시 처인구 원삼면 원양로 487    12036.00
# 1    A  1068197118        전북특별자치도 완주군 봉동읍 테크노밸리3로 65, 전주현대글로비스    26558.20
# 2    A  1068197118                        충청북도 음성군 삼성면 대성로 355    35398.81
# 3    A  1068197118                    광주광역시 광산구 평동산단외로 56 (용동)     5950.06
# 4    A  1068197118      대전광역시 대덕구 대전로1331번길 205, 롯데택배 5층 (대화동)     1322.32
# 5    A  1068197118                   경기도 용인시 처인구 백암면 죽양대로 1182        0.00
# 6    A  1068197118                 충청남도 천안시 동남구 병천면 충절로 1529-5     1320.00
# 7    A  1068197118       경기도 김포시 고촌읍 아라육로152번길 115, 케이로지스필드 1층      632.02
# 8    A  1068197118  경상남도 양산시 물금읍 제방로 245, 양산ICD5단지(제44동, 제62동)     5231.29
# 9    A  1068197118                    경상북도 경산시 와촌면 상암길37길 75-9     5190.10
# 10   A  1068197118                  충청북도 청주시 상당구 가덕면 상장인차로 188    14241.93
# 11   A  1068197118               충청북도 청주시 서원구 남이면 저산척북로 203-44     6600.00
# 12   A  1068197118                충청남도 당진시 송산면 가곡로 21 (현대글로비스)    16490.55
#
#     냉동냉장창고면적(m²)   관련법률                                        취급품목  \
# 0           0.00  물류시설법                        가구, 소파, 테이블, 일반공산품 등
# 1           0.00  물류시설법                                      자동차 부품
# 2           0.00  물류시설법  음료(페트병, 유리병), 부자재(박스, 공캔 등), 가구, 배터리셀 모듈 등
# 3           0.00  물류시설법                  제과, 아이스크림, 냉동만두, 매일유업 원부자재
# 4           0.00  물류시설법                                         제과류
# 5        6823.00  물류시설법                              냉동식품, 음료수, 초코류
# 6           0.00  물류시설법                                      애완동물사료
# 7        2892.81  물류시설법                                  생활용품 및 식품류
# 8           0.00  물류시설법                        아이스크림, 냉동만두, 해태크라운제과
# 9           0.00  물류시설법                                         제과류
# 10          0.00  물류시설법                              인테리어 내장재 및 부자재
# 11          0.00  물류시설법                                   샤시, 기타부자재
# 12          0.00  물류시설법                                 철강제품(냉연,열연)
#
#            위도          경도
# 0   37.174060  127.308791
# 1   35.974568  127.119370
# 2   37.004451  127.498024
# 3   35.130701  126.751846
# 4   36.367107  127.400822
# 5   37.161858  127.381869
# 6   36.767473  127.323373
# 7   37.599007  126.784106
# 8   35.313620  129.017820
# 9   35.946651  128.850721
# 10  36.528930  127.519436
# 11  36.566511  127.411278
# 12  36.977735  126.687840

# %%
for i in HD.index:
    name = HD.loc[i, '상호명']
    lat = HD.loc[i, '위도']
    lon = HD.loc[i, '경도']
    marker = folium.Marker([lat,lon], popup=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78be8411377028d33fb7ac6bc8b08372 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78be8411377028d33fb7ac6bc8b08372&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78be8411377028d33fb7ac6bc8b08372 = L.map(
#                 &quot;map_78be8411377028d33fb7ac6bc8b08372&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cd1bb70fb9658842d611d96c2f91b89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2cd1bb70fb9658842d611d96c2f91b89.addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#             tile_layer_2cd1bb70fb9658842d611d96c2f91b89.addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#             var marker_f72d55e1ef53dd41cbe98ff99f23bc7b = L.marker(
#                 [37.17406005, 127.3087907],
#                 {}
#             ).addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#         var popup_5654b76ff9e4979d69520492e82e4918 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3ebd9102386f1457260917bb5650922 = $(`&lt;div id=&quot;html_c3ebd9102386f1457260917bb5650922&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;현대글로비스 주식회사&lt;/div&gt;`)[0];
#                 popup_5654b76ff9e4979d69520492e82e4918.setContent(html_c3ebd9102386f1457260917bb5650922);
#
#
#
#         marker_f72d55e1ef53dd41cbe98ff99f23bc7b.bindPopup(popup_5654b76ff9e4979d69520492e82e4918)
#         ;
#
#
#
#
#             var marker_2566a4b4be6cb6d74aea367230ef6084 = L.marker(
#                 [35.97456775, 127.1193703],
#                 {}
#             ).addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#         var popup_d5d4bec0974c44f4c379e967c9880e3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a120a852f8d3f6be1fd925aa6eeceec9 = $(`&lt;div id=&quot;html_a120a852f8d3f6be1fd925aa6eeceec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;현대글로비스(주)&lt;/div&gt;`)[0];
#                 popup_d5d4bec0974c44f4c379e967c9880e3b.setContent(html_a120a852f8d3f6be1fd925aa6eeceec9);
#
#
#
#         marker_2566a4b4be6cb6d74aea367230ef6084.bindPopup(popup_d5d4bec0974c44f4c379e967c9880e3b)
#         ;
#
#
#
#
#             var marker_5af4df4510e1472c16a2245e9c008861 = L.marker(
#                 [37.0044509, 127.4980243],
#                 {}
#             ).addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#         var popup_5b85a1d738bf20f48e1b91c06870d39c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60ed2ee4542616997289c20d94525404 = $(`&lt;div id=&quot;html_60ed2ee4542616997289c20d94525404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;현대글로비스 주식회사&lt;/div&gt;`)[0];
#                 popup_5b85a1d738bf20f48e1b91c06870d39c.setContent(html_60ed2ee4542616997289c20d94525404);
#
#
#
#         marker_5af4df4510e1472c16a2245e9c008861.bindPopup(popup_5b85a1d738bf20f48e1b91c06870d39c)
#         ;
#
#
#
#
#             var marker_1032cb07497a7a5b9cd8059a5d051fb3 = L.marker(
#                 [35.1307005, 126.7518464],
#                 {}
#             ).addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#         var popup_ea729c0340d0bcbe012c173dc8695de3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_691bac2fc9daf721978624185c16157c = $(`&lt;div id=&quot;html_691bac2fc9daf721978624185c16157c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;현대글로비스 주식회사&lt;/div&gt;`)[0];
#                 popup_ea729c0340d0bcbe012c173dc8695de3.setContent(html_691bac2fc9daf721978624185c16157c);
#
#
#
#         marker_1032cb07497a7a5b9cd8059a5d051fb3.bindPopup(popup_ea729c0340d0bcbe012c173dc8695de3)
#         ;
#
#
#
#
#             var marker_4edef2bad2b38af1f4c4b45f3eb2d219 = L.marker(
#                 [36.36710653, 127.400822],
#                 {}
#             ).addTo(map_78be8411377028d33fb7ac6bc8b08372);
#
#
#         var popup_b170455caa3fb8d3b5baec89a277f6bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8bdff480b8ef127ce985dbdc5d9a012 = $(`&lt;div id=&quot;html_c8bdff480b8ef127ce985dbdc5d9a012&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;현대글로비스(주)&lt;/div&gt;`)[0];
#                 popup_b170455caa3fb8d3b5baec89a277f6bc.setContent(html_c8bdff480b8ef127ce985dbdc5d9a012);
#
#
#
#         marker_4edef2bad2b38af1f4c4b45f3eb2d219.bindPopup(popup_b170455caa3fb8d3b5baec89a277f6bc)
#         ;
#
#
#
#
#             var marker_c81081415abbf07afd5cc63d5bd9d900 = L.marker(

# %%
map2 = folium.Map(location=[36, 127], zoom_start=7)
for i in HD.index:
    name = HD.loc[i, '상호명']
    lat = HD.loc[i, '위도']
    lon = HD.loc[i, '경도']
    if HD['상호명'][i] == 'A':
        code_color = 'red'
    else: code_color = 'black'
    marker = folium.Marker([lat,lon], popup=name, icon=folium.Icon(color=code_color)).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82d967dd3b94748843731479726aa7df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82d967dd3b94748843731479726aa7df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82d967dd3b94748843731479726aa7df = L.map(
#                 &quot;map_82d967dd3b94748843731479726aa7df&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2341e12b5f49bc27d8a6ad11c424280 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2341e12b5f49bc27d8a6ad11c424280.addTo(map_82d967dd3b94748843731479726aa7df);
#
#
#             var marker_f57753be733d82f84ba992dedc230bd5 = L.marker(
#                 [37.17406005, 127.3087907],
#                 {}
#             ).addTo(map_82d967dd3b94748843731479726aa7df);
#
#
#             var icon_a9aca4b20c25eab4b4b10bf2ca402850 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f57753be733d82f84ba992dedc230bd5.setIcon(icon_a9aca4b20c25eab4b4b10bf2ca402850);
#
#
#         var popup_0361cd9c1f5b9609de8205d9b366d8e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_65f9fbf02f37df0c0d1491e43968047a = $(`&lt;div id=&quot;html_65f9fbf02f37df0c0d1491e43968047a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&lt;/div&gt;`)[0];
#                 popup_0361cd9c1f5b9609de8205d9b366d8e9.setContent(html_65f9fbf02f37df0c0d1491e43968047a);
#
#
#
#         marker_f57753be733d82f84ba992dedc230bd5.bindPopup(popup_0361cd9c1f5b9609de8205d9b366d8e9)
#         ;
#
#
#
#
#             var marker_27d2029a744eae221f297579abc5fec9 = L.marker(
#                 [35.97456775, 127.1193703],
#                 {}
#             ).addTo(map_82d967dd3b94748843731479726aa7df);
#
#
#             var icon_393713625b011951e39581e29e2c1dfa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_27d2029a744eae221f297579abc5fec9.setIcon(icon_393713625b011951e39581e29e2c1dfa);
#
#
#         var popup_1ea9ee89decab139ca7277635b198dec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2469712b0943142bb8c86815d7c1ca41 = $(`&lt;div id=&quot;html_2469712b0943142bb8c86815d7c1ca41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&lt;/div&gt;`)[0];
#                 popup_1ea9ee89decab139ca7277635b198dec.setContent(html_2469712b0943142bb8c86815d7c1ca41);
#
#
#
#         marker_27d2029a744eae221f297579abc5fec9.bindPopup(popup_1ea9ee89decab139ca7277635b198dec)
#         ;
#
#
#
#
#             var marker_ce71064e2cdc683531ae21c6577c0c10 = L.marker(
#                 [37.0044509, 127.4980243],
#                 {}
#             ).addTo(map_82d967dd3b94748843731479726aa7df);
#
#
#             var icon_002f7fc10b3a9967f860719e497c35a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ce71064e2cdc683531ae21c6577c0c10.setIcon(icon_002f7fc10b3a9967f860719e497c35a7);
#
#
#         var popup_98b893fba6285184429dfb80a7e42e40 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f659dc76ddf630099d212e105ad5288a = $(`&lt;div id=&quot;html_f659dc76ddf630099d212e105ad5288a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A&lt;/div&gt;`)[0];
#                 popup_98b893fba6285184429dfb80a7e42e40.setContent(html_f659dc76ddf630099d212e105ad5288a);
#
#
#
#         marker_ce71064e2cdc683531ae21c6577c0c10.bindPopup(popup_98b893fba6285184429dfb80a7e42e40)
#         ;
#
#
#
#
#             var marker_c59ecc57b6859ef371b8ae9c0196c67e = L.marker(
#                 [35.1307005, 126.7518464],
#                 {}
#             ).addTo(map_82d967dd3b94748843731479726aa7df);
#
#
#             var icon_36543b6dbfe925ad8a2969436e060534 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot

# %%
map3 = folium.Map(location=[36, 127], zoom_start=7)

from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(map3)

for lat, long in zip(HD.위도, HD.경도):
    folium.Marker([lat, long]).add_to(marker_cluster)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b90a3f27c5717b641ee2095e569c086 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b90a3f27c5717b641ee2095e569c086&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b90a3f27c5717b641ee2095e569c086 = L.map(
#                 &quot;map_0b90a3f27c5717b641ee2095e569c086&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb25373ee46d52545d815cc94071d63c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb25373ee46d52545d815cc94071d63c.addTo(map_0b90a3f27c5717b641ee2095e569c086);
#
#
#             var marker_cluster_c9fe6feec1b085091372395211a62f28 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_09584192085b51995e09ee0d63e7cdb1 = L.marker(
#                 [37.17406005, 127.3087907],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_9fb8feb4b581318ee79943ee1a3743e4 = L.marker(
#                 [35.97456775, 127.1193703],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_aa93e43c1373fc9f143881a1c38382da = L.marker(
#                 [37.0044509, 127.4980243],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_48aecd6ff427b276123c77a52c716064 = L.marker(
#                 [35.1307005, 126.7518464],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_0f1a38d957b3e22c3f82bf083d766700 = L.marker(
#                 [36.36710653, 127.400822],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_19c4420c615f518c31ca5ca1e9261af4 = L.marker(
#                 [37.16185826, 127.3818686],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_cb6501c36086aead18d400541bcc9ff1 = L.marker(
#                 [36.76747314, 127.3233733],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_c4467df673ac353d2499b4dbb812b631 = L.marker(
#                 [37.59900675, 126.7841061],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_95637a6ed8fa27e3328393dea9bba398 = L.marker(
#                 [35.31362026, 129.0178197],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_94926fdf32f32119522df8622d302f3f = L.marker(
#                 [35.946651, 128.850721],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_a65aa87164e3fdf3ee102cf02d7dc234 = L.marker(
#                 [36.52892982, 127.5194363],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_f91496534dfadd76e50a25474e67e3ac = L.marker(
#                 [36.56651072, 127.4112778],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             var marker_673bdd109b79fa90eb7a1113e5638d66 = L.marker(
#                 [36.9777354, 126.6878399],
#                 {}
#             ).addTo(marker_cluster_c9fe6feec1b085091372395211a62f28);
#
#
#             marker_cluster_c9fe6feec1b085091372395211a62f28.addTo(map_0b90a3f27c5717b641ee2095e569c086);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
