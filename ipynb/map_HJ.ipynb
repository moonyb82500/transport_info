# %%
import pandas as pd

# %%
import folium
map = folium.Map(location=[36,127],zoom_start=7)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a558e11255c1588011035c3d2be9841 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a558e11255c1588011035c3d2be9841&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a558e11255c1588011035c3d2be9841 = L.map(
#                 &quot;map_5a558e11255c1588011035c3d2be9841&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf187f0feb8d4a40abafe822635cffa5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cf187f0feb8d4a40abafe822635cffa5.addTo(map_5a558e11255c1588011035c3d2be9841);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
HJ = pd.read_csv('한진_위도경도.csv')
HJ
# Out:
#    상호명       사업자번호                                                소재지  \
# 0    E  2018102823                           충청북도 청주시 서원구 남이면 청남로 845
# 1    E  2018102823                           인천광역시 서구 북항단지로 110 (원창동)
# 2    E  2018102823  경기도 군포시 번영로 82, 한국복합물류(주) 관리동 H동 1,2,3,4,5층 (부곡동)
# 3    E  2028102823                          전북특별자치도 군산시 공항로 587 (개사동)
# 4    E  2018102823                            충청남도 서산시 남부순환로 161 (장동)
# 5    E  2018102823                             경상남도 진주시 정촌면 뿌리산단로 102
# 6    E  2018102823                              전라남도 나주시 금영로 459(평산동)
# 7    E  2018102823                                경기도 이천시 대월면 대월로 256
# 8    E  2018102823                       부산광역시 사상구 낙동대로882번길 17 (감전동)
# 9    E  2018102823              부산광역시 남구 북항로 132, (주)한진감만동택배터미널 (감만동)
# 10   E  2018102823                         광주광역시 광산구 손재로 366-55 (오선동)
# 11   E  2018102823                          울산광역시 남구 사평로 227-50 (선암동)
# 12   E  2018102823           대전광역시 유성구 대정로 68, (주)한진대전택배터미널 301호(대정동)
# 13   E  2018102823                       대전광역시 대덕구 대화로106번길 111 (대화동)
# 14   E  2018102823                          제주특별자치도 제주시 임항로 201 (건입동)
# 15   E  2018102823               인천광역시 중구 자유무역로 232, 한진 지디씨물류센터 (운서동)
# 16   E  2018102823                               경기도 이천시 부발읍 황무로 1780
# 17   E  2018102823  세종특별자치시 부강면 연청로 745-46, 3동 화물취급장A(나동), 1동 화물취급...
# 18   E  2018102823              서울특별시 송파구 송파대로 55, B동 2층 (장지동,서울복합물류)
# 19   E  2018102823    경상북도 포항시 남구 대송로253번길 71, (주)한진포항자동차중기정비공장 (송내동)
# 20   E  2018102823                           서울특별시 강서구 오정로 602 (외발산동)
# 21   E  1198505359                         서울특별시 금천구 가산디지털2로 83 (가산동)
# 22   E  2018102823                            서울특별시 구로구 경인로 110 (오류동)
# 23   E  2018102823                            대구광역시 달성군 가창면 용계리 452번지
# 24   E  2018102823                               전라남도 여수시 대평길 22(해산동)
# 25   E  2018102823                            전라남도 순천시 해룡면 여순로 1371-9
# 26   E  2018102823                        충청북도 청주시 청원구 2순환로 426 (사천동)
# 27   E  2018102823                         경기도 구리시 동구릉로460번길 29 (사노동)
# 28   E  2018102823                 경상남도 양산시 물금읍 제방로 205, (양산ICD내 6단지)
# 29   E  2018102823                          경기도 고양시 덕양구 대주로 499 (주교동)
# 30   E  2018502823                           인천광역시 부평구 부평북로 295 (갈산동)
# 31   E  2018102823                        전북특별자치도 전주시 덕진구 정암길 23 (장동)
# 32   E  2018102823                            인천광역시 중구 인항로 39 (신흥동3가)
# 33   E  2018102823                             경기도 용인시 처인구 백암면 백암로 17
# 34   E  2018102823                               경기도 양주시 은현면 화합로 1187
# 35   E  2018102823                          경기도 안산시 단원구 번영1로 35 (성곡동)
up=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a558e11255c1588011035c3d2be9841 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a558e11255c1588011035c3d2be9841&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a558e11255c1588011035c3d2be9841 = L.map(
#                 &quot;map_5a558e11255c1588011035c3d2be9841&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf187f0feb8d4a40abafe822635cffa5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cf187f0feb8d4a40abafe822635cffa5.addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#             tile_layer_cf187f0feb8d4a40abafe822635cffa5.addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#             var marker_81d9f0bfc7265c99eb199ac291f62bfb = L.marker(
#                 [36.5289654, 127.4292044],
#                 {}
#             ).addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#         var popup_db8cc3036a8ff6138a7392972fa822f3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_39f9bc55ceff58d338b564434578feb4 = $(`&lt;div id=&quot;html_39f9bc55ceff58d338b564434578feb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_db8cc3036a8ff6138a7392972fa822f3.setContent(html_39f9bc55ceff58d338b564434578feb4);
#
#
#
#         marker_81d9f0bfc7265c99eb199ac291f62bfb.bindPopup(popup_db8cc3036a8ff6138a7392972fa822f3)
#         ;
#
#
#
#
#             var marker_7125b541854784215c376f288a74ade2 = L.marker(
#                 [37.5017131, 126.6196592],
#                 {}
#             ).addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#         var popup_5f974c928cfe71f91cb30e1c3ceaeb6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e4b63c7a1c378025f3199cedeb50b0d = $(`&lt;div id=&quot;html_3e4b63c7a1c378025f3199cedeb50b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_5f974c928cfe71f91cb30e1c3ceaeb6b.setContent(html_3e4b63c7a1c378025f3199cedeb50b0d);
#
#
#
#         marker_7125b541854784215c376f288a74ade2.bindPopup(popup_5f974c928cfe71f91cb30e1c3ceaeb6b)
#         ;
#
#
#
#
#             var marker_e14a1ceed8409ae1695909b62bf1ab65 = L.marker(
#                 [37.3309195, 126.9371945],
#                 {}
#             ).addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#         var popup_a31fcb2095a12a7b78b9d9e2d3849aa0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80939a7e35e9be59b97518d9b8edec90 = $(`&lt;div id=&quot;html_80939a7e35e9be59b97518d9b8edec90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_a31fcb2095a12a7b78b9d9e2d3849aa0.setContent(html_80939a7e35e9be59b97518d9b8edec90);
#
#
#
#         marker_e14a1ceed8409ae1695909b62bf1ab65.bindPopup(popup_a31fcb2095a12a7b78b9d9e2d3849aa0)
#         ;
#
#
#
#
#             var marker_6024f56f76d4d05443ac44a247959f82 = L.marker(
#                 [35.9593605, 126.6616173],
#                 {}
#             ).addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#         var popup_4f48f1797f3d2d5683a005de8b4c8e9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b810647f0a95ca73a359032946d0034 = $(`&lt;div id=&quot;html_9b810647f0a95ca73a359032946d0034&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_4f48f1797f3d2d5683a005de8b4c8e9c.setContent(html_9b810647f0a95ca73a359032946d0034);
#
#
#
#         marker_6024f56f76d4d05443ac44a247959f82.bindPopup(popup_4f48f1797f3d2d5683a005de8b4c8e9c)
#         ;
#
#
#
#
#             var marker_242ec78a2ff13cc1a36558e8ae56becb = L.marker(
#                 [36.7350302, 126.487375],
#                 {}
#             ).addTo(map_5a558e11255c1588011035c3d2be9841);
#
#
#         var popup_561b0bcc095aaaa6e5064ebc45fea02d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5888262b8c954f55aaecd2048e13d9af = $(`&lt;div id=&quot;html_5888262b8c954f55aaecd2048e13d9af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_561b0bcc095aaaa6e5064ebc45fea02d.setContent(html_5888262b8c954f55aaecd2048e13d9af);
#
#
#
#         marker_242ec78a2ff13cc1a36558e8ae56becb.bindPopup(popup_561b0bcc095aaaa6e5064ebc45fea02d)
#         ;
#
#
#
#
#             var marker_a7ff533f02b5265b0c46f93a6d040ca9 = L.marker(
#                 [35.1138693, 128.105683],

# %%
map2 = folium.Map(location=[36, 127], zoom_start=7)
for i in HJ.index:
    name = HJ.loc[i, '상호명']
    lat = HJ.loc[i, '위도']
    lon = HJ.loc[i, '경도']
    if HJ['상호명'][i] == 'E':
        code_color = 'purple'
    else: code_color = 'black'
    marker = folium.Marker([lat,lon], popup=name, icon=folium.Icon(color=code_color)).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7fe392af1972ade0299a70a2897f29b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7fe392af1972ade0299a70a2897f29b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7fe392af1972ade0299a70a2897f29b = L.map(
#                 &quot;map_a7fe392af1972ade0299a70a2897f29b&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f615e437cba16883670539d5af19c00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2f615e437cba16883670539d5af19c00.addTo(map_a7fe392af1972ade0299a70a2897f29b);
#
#
#             var marker_2dd4b857bc0f095e8ccb96e9d5910e23 = L.marker(
#                 [36.5289654, 127.4292044],
#                 {}
#             ).addTo(map_a7fe392af1972ade0299a70a2897f29b);
#
#
#             var icon_9bb1b862467c5b3632e329151274756b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2dd4b857bc0f095e8ccb96e9d5910e23.setIcon(icon_9bb1b862467c5b3632e329151274756b);
#
#
#         var popup_1bb95e774f8195e26f50849720135573 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bdb38c1c0f75d9d6f67482d1bfe60c9d = $(`&lt;div id=&quot;html_bdb38c1c0f75d9d6f67482d1bfe60c9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_1bb95e774f8195e26f50849720135573.setContent(html_bdb38c1c0f75d9d6f67482d1bfe60c9d);
#
#
#
#         marker_2dd4b857bc0f095e8ccb96e9d5910e23.bindPopup(popup_1bb95e774f8195e26f50849720135573)
#         ;
#
#
#
#
#             var marker_2655d76f20183c036e9ef9ceba0b4122 = L.marker(
#                 [37.5017131, 126.6196592],
#                 {}
#             ).addTo(map_a7fe392af1972ade0299a70a2897f29b);
#
#
#             var icon_eb3952f2f9c4fed08e37a94d2500985b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2655d76f20183c036e9ef9ceba0b4122.setIcon(icon_eb3952f2f9c4fed08e37a94d2500985b);
#
#
#         var popup_d094eb006e8dcbaf68e3c5e1d9f607a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bf21212c927a92e209ac8ad6c0bf33c = $(`&lt;div id=&quot;html_9bf21212c927a92e209ac8ad6c0bf33c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_d094eb006e8dcbaf68e3c5e1d9f607a9.setContent(html_9bf21212c927a92e209ac8ad6c0bf33c);
#
#
#
#         marker_2655d76f20183c036e9ef9ceba0b4122.bindPopup(popup_d094eb006e8dcbaf68e3c5e1d9f607a9)
#         ;
#
#
#
#
#             var marker_f2261706230c389540d6be39e7858219 = L.marker(
#                 [37.3309195, 126.9371945],
#                 {}
#             ).addTo(map_a7fe392af1972ade0299a70a2897f29b);
#
#
#             var icon_5bfcb5866653884ceaeba011a9be8c2a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f2261706230c389540d6be39e7858219.setIcon(icon_5bfcb5866653884ceaeba011a9be8c2a);
#
#
#         var popup_0455555387b3ee31a2cfdd3e9930f71a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e25a8bfee08120223cd19ed4d28648ac = $(`&lt;div id=&quot;html_e25a8bfee08120223cd19ed4d28648ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;E&lt;/div&gt;`)[0];
#                 popup_0455555387b3ee31a2cfdd3e9930f71a.setContent(html_e25a8bfee08120223cd19ed4d28648ac);
#
#
#
#         marker_f2261706230c389540d6be39e7858219.bindPopup(popup_0455555387b3ee31a2cfdd3e9930f71a)
#         ;
#
#
#
#
#             var marker_48e52f62720ba42f57d2ad85e3c546ee = L.marker(
#                 [35.9593605, 126.6616173],
#                 {}
#             ).addTo(map_a7fe392af1972ade0299a70a2897f29b);
#
#
#             var icon_63c121990b437c1c31280fda6620e26c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;p

# %%
map3 = folium.Map(location=[36, 127], zoom_start=7)

from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(map3)

for lat, long in zip(HJ.위도, HJ.경도):
    folium.Marker([lat, long]).add_to(marker_cluster)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1931c23e22ed46df9b2726ce3c804a2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1931c23e22ed46df9b2726ce3c804a2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1931c23e22ed46df9b2726ce3c804a2f = L.map(
#                 &quot;map_1931c23e22ed46df9b2726ce3c804a2f&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0bd9a6e450d85b11bf53fed625828d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e0bd9a6e450d85b11bf53fed625828d9.addTo(map_1931c23e22ed46df9b2726ce3c804a2f);
#
#
#             var marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_601529d25c4b3d8e1ceb09144750c434 = L.marker(
#                 [36.5289654, 127.4292044],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_1c3bfff9b4553a8ae8d80401de30b0b6 = L.marker(
#                 [37.5017131, 126.6196592],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_4da4670580c0d5b4f68a6999f39ccd94 = L.marker(
#                 [37.3309195, 126.9371945],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_18fa0ef129aa40f5ed0379d297986cce = L.marker(
#                 [35.9593605, 126.6616173],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_4be954ffe90ebf4d582037d1945f3cdf = L.marker(
#                 [36.7350302, 126.487375],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_06d22c824f75ff4d0aab0e3630a91d73 = L.marker(
#                 [35.1138693, 128.105683],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_3aefd547622933737925222d596d40be = L.marker(
#                 [34.9960015, 126.7551006],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_064f8f8f9edd8f56e1ceba369fd98863 = L.marker(
#                 [37.1836507, 127.4931826],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_5a90860eb5105a0c1df61a0a4d55a5a3 = L.marker(
#                 [35.1398396, 128.971726],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_9a949644fa4164e1e3f49c5cbd0218ae = L.marker(
#                 [35.1094576, 129.0794875],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_48638d1695e438292dbf4e57ba368c99 = L.marker(
#                 [35.1993977, 126.8011065],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_0d635a05f075c7dfc8c14d4901b9eb03 = L.marker(
#                 [35.5088777, 129.3324257],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_f9ac5ddd37664b1d8cbdbbca0d916e60 = L.marker(
#                 [36.3176625, 127.3213713],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_58a5f00c4f30ad4a6222f35ba8201246 = L.marker(
#                 [36.3711833, 127.4050933],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_66e671b8ba957c69121ec7b8f5d2de6e = L.marker(
#                 [33.5235192, 126.5501442],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_4b40c0f84e8dcd834df29950d0351458 = L.marker(
#                 [37.4877799, 126.4725366],
#                 {}
#             ).addTo(marker_cluster_a1d31399bb1c2492a5f9d8be8641ff7b);
#
#
#             var marker_c1fc597d9b64bf9bbb831fdeeda323f9 = L.marker(
#                 [37.2645279, 127.5181214],
#                 {}
#             ).addTo(mark
