# %%
import pandas as pd

# %%
import folium
map = folium.Map(location=[36,127],zoom_start=7)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35f92e54082b0f7d8c9fa3ec64d8be03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35f92e54082b0f7d8c9fa3ec64d8be03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35f92e54082b0f7d8c9fa3ec64d8be03 = L.map(
#                 &quot;map_35f92e54082b0f7d8c9fa3ec64d8be03&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2088fe7b484f98c644c7b74019f558d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2088fe7b484f98c644c7b74019f558d3.addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
LT = pd.read_csv('롯데글로벌로지스_위도경도.csv')
LT
# Out:
#    상호명       사업자번호                                     소재지  일반창고면적(m²)  \
# 0    D  1028123012                   부산광역시 남구 우암로 285(문현동)     7256.00
# 1    D  1028123012                 부산광역시 기장군 장안읍 반룡산단로 110     5883.55
# 2    D  1028123012     경상북도 경산시 진량읍 공단11로 215, 경산복합물류센터 5층    28143.60
# 3    D  1028123012        경기도 시흥시 수인로 2127-11, (주)한샘 (조남동)     8904.05
# 4    D  1028123012               부산광역시 강서구 미음국제2로 58 (미음동)     4696.00
# ..  ..         ...                                     ...         ...
# 82   D  1028123012                 충청남도 천안시 서북구 성거읍 삼곡2길 6     4628.09
# 83   D  1028123012             충청남도 천안시 서북구 성거읍 망향로 903-11     2250.00
# 84   D  1028123012                   경기도 광주시 오포로 614 (문형동)     4628.92
# 85   D  1028123012  경기도 이천시 마장면 덕평로 831-59 (현대로지스틱스덕평물류센터)   126251.00
# 86   D  1028123012           경상남도 창원시 의창구 차상로106번길 4 (팔용동)     1240.00
#
#     냉동냉장창고면적(m²)   관련법률             취급품목         위도          경도
# 0            0.0  물류시설법            택배소화물  35.124847  129.074308
# 1            0.0  물류시설법             택배박스  35.331239  129.250395
# 2            0.0  물류시설법  식음료, 생활용품, 잡화 등  35.866946  128.840640
# 3            0.0  물류시설법             택배물품  37.377352  126.871291
# 4         4045.0  물류시설법       건과제품, 빙과제품  35.148291  128.870275
# ..           ...    ...              ...        ...         ...
# 82           0.0  물류시설법              화장품  36.894555  127.186896
# 83           0.0  물류시설법       택배소화물,의류 등  36.888625  127.205004
# 84           0.0  물류시설법      유기농제품, 가공식품  37.370526  127.232461
# 85           0.0  물류시설법           의류, 잡화  37.254260  127.360784
# 86           0.0  물류시설법               택배  35.234493  128.636680
#
# [87 rows x 9 columns]

# %%
for i in LT.index:
    name = LT.loc[i, '상호명']
    lat = LT.loc[i, '위도']
    lon = LT.loc[i, '경도']
    marker = folium.Marker([lat,lon], popup=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35f92e54082b0f7d8c9fa3ec64d8be03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35f92e54082b0f7d8c9fa3ec64d8be03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35f92e54082b0f7d8c9fa3ec64d8be03 = L.map(
#                 &quot;map_35f92e54082b0f7d8c9fa3ec64d8be03&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2088fe7b484f98c644c7b74019f558d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2088fe7b484f98c644c7b74019f558d3.addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#             tile_layer_2088fe7b484f98c644c7b74019f558d3.addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#             var marker_8e826bba70ee5b3c5e775c0fb576005b = L.marker(
#                 [35.12484689, 129.0743079],
#                 {}
#             ).addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#         var popup_1348e12d8d81aeb382941e77cbb5e8ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97194ce59c4a1c4a42804f5037de4f42 = $(`&lt;div id=&quot;html_97194ce59c4a1c4a42804f5037de4f42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_1348e12d8d81aeb382941e77cbb5e8ac.setContent(html_97194ce59c4a1c4a42804f5037de4f42);
#
#
#
#         marker_8e826bba70ee5b3c5e775c0fb576005b.bindPopup(popup_1348e12d8d81aeb382941e77cbb5e8ac)
#         ;
#
#
#
#
#             var marker_fa1ac02804a00dddda442a7b2ff0b984 = L.marker(
#                 [35.33123853, 129.2503951],
#                 {}
#             ).addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#         var popup_75cc309b357ca7711d290424ed45d37d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_877e1f789f4dc4120da62da6fb652bc7 = $(`&lt;div id=&quot;html_877e1f789f4dc4120da62da6fb652bc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_75cc309b357ca7711d290424ed45d37d.setContent(html_877e1f789f4dc4120da62da6fb652bc7);
#
#
#
#         marker_fa1ac02804a00dddda442a7b2ff0b984.bindPopup(popup_75cc309b357ca7711d290424ed45d37d)
#         ;
#
#
#
#
#             var marker_a0c72de0d1919bf5cedbdb47d27f8442 = L.marker(
#                 [35.86694595, 128.84064],
#                 {}
#             ).addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#         var popup_cc54bad71572fddc809834602b323846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ce45e7fa08f6bc6491bba73d97ce877 = $(`&lt;div id=&quot;html_0ce45e7fa08f6bc6491bba73d97ce877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_cc54bad71572fddc809834602b323846.setContent(html_0ce45e7fa08f6bc6491bba73d97ce877);
#
#
#
#         marker_a0c72de0d1919bf5cedbdb47d27f8442.bindPopup(popup_cc54bad71572fddc809834602b323846)
#         ;
#
#
#
#
#             var marker_2b64271b2997ef2e242afe293f4d9e9b = L.marker(
#                 [37.37735165, 126.8712912],
#                 {}
#             ).addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#         var popup_ad5ad2b358cdfa80cb576e53dfdf6ce8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce3dd3cf3ee56e86b5c83708a50db853 = $(`&lt;div id=&quot;html_ce3dd3cf3ee56e86b5c83708a50db853&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_ad5ad2b358cdfa80cb576e53dfdf6ce8.setContent(html_ce3dd3cf3ee56e86b5c83708a50db853);
#
#
#
#         marker_2b64271b2997ef2e242afe293f4d9e9b.bindPopup(popup_ad5ad2b358cdfa80cb576e53dfdf6ce8)
#         ;
#
#
#
#
#             var marker_11bb18abd8580fc55b9cf5b180126e38 = L.marker(
#                 [35.14829091, 128.8702754],
#                 {}
#             ).addTo(map_35f92e54082b0f7d8c9fa3ec64d8be03);
#
#
#         var popup_301e672236708acb4bcd55bdb1b8e527 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f6dcb7f03fdaa288e0013da7e6833fc = $(`&lt;div id=&quot;html_8f6dcb7f03fdaa288e0013da7e6833fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_301e672236708acb4bcd55bdb1b8e527.setContent(html_8f6dcb7f03fdaa288e0013da7e6833fc);
#
#
#
#         marker_11bb18abd8580fc55b9cf5b180126e38.bindPopup(popup_301e672236708acb4bcd55bdb1b8e527)
#         ;
#
#
#
#
#             var marker_bf497a75664c74b5ef88d0626b4dd1dc = L.marker(
#                 [35.16506354, 126.8017562],

# %%
map2 = folium.Map(location=[36, 127], zoom_start=7)
for i in LT.index:
    name = LT.loc[i, '상호명']
    lat = LT.loc[i, '위도']
    lon = LT.loc[i, '경도']
    if LT['상호명'][i] == 'D':
        code_color = 'blue'
    else: code_color = 'black'
    marker = folium.Marker([lat,lon], popup=name, icon=folium.Icon(color=code_color)).add_to(map2)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef041c31b4cd7a5c732baec37e892d69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef041c31b4cd7a5c732baec37e892d69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef041c31b4cd7a5c732baec37e892d69 = L.map(
#                 &quot;map_ef041c31b4cd7a5c732baec37e892d69&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9309b8ebf172982ad1461a85f7179a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d9309b8ebf172982ad1461a85f7179a5.addTo(map_ef041c31b4cd7a5c732baec37e892d69);
#
#
#             var marker_93bedf86107d090a54a04e4dc9930089 = L.marker(
#                 [35.12484689, 129.0743079],
#                 {}
#             ).addTo(map_ef041c31b4cd7a5c732baec37e892d69);
#
#
#             var icon_97f5239289773f10cf0305050e9fd395 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93bedf86107d090a54a04e4dc9930089.setIcon(icon_97f5239289773f10cf0305050e9fd395);
#
#
#         var popup_5078882f15ad964ea0ee585d9be42a60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b40848d3e911f9d62a2f76889dd35975 = $(`&lt;div id=&quot;html_b40848d3e911f9d62a2f76889dd35975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_5078882f15ad964ea0ee585d9be42a60.setContent(html_b40848d3e911f9d62a2f76889dd35975);
#
#
#
#         marker_93bedf86107d090a54a04e4dc9930089.bindPopup(popup_5078882f15ad964ea0ee585d9be42a60)
#         ;
#
#
#
#
#             var marker_b9a79568699d7e8c775cce174d0a50e6 = L.marker(
#                 [35.33123853, 129.2503951],
#                 {}
#             ).addTo(map_ef041c31b4cd7a5c732baec37e892d69);
#
#
#             var icon_d2d4817efe8a7247dad1c2ea717fbb4e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b9a79568699d7e8c775cce174d0a50e6.setIcon(icon_d2d4817efe8a7247dad1c2ea717fbb4e);
#
#
#         var popup_3be38fd225b018980d873bf24b9dcdd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b86f35b3bd208281984b5d2b09b91a5 = $(`&lt;div id=&quot;html_1b86f35b3bd208281984b5d2b09b91a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_3be38fd225b018980d873bf24b9dcdd9.setContent(html_1b86f35b3bd208281984b5d2b09b91a5);
#
#
#
#         marker_b9a79568699d7e8c775cce174d0a50e6.bindPopup(popup_3be38fd225b018980d873bf24b9dcdd9)
#         ;
#
#
#
#
#             var marker_d7b2e319cfae61342053da2b6143a581 = L.marker(
#                 [35.86694595, 128.84064],
#                 {}
#             ).addTo(map_ef041c31b4cd7a5c732baec37e892d69);
#
#
#             var icon_a1a616084ca14b9bd117e839b097a254 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7b2e319cfae61342053da2b6143a581.setIcon(icon_a1a616084ca14b9bd117e839b097a254);
#
#
#         var popup_d30301a3b90e31d457e419d4b3fae090 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3007a233df0aa047310c711b8097e6a8 = $(`&lt;div id=&quot;html_3007a233df0aa047310c711b8097e6a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D&lt;/div&gt;`)[0];
#                 popup_d30301a3b90e31d457e419d4b3fae090.setContent(html_3007a233df0aa047310c711b8097e6a8);
#
#
#
#         marker_d7b2e319cfae61342053da2b6143a581.bindPopup(popup_d30301a3b90e31d457e419d4b3fae090)
#         ;
#
#
#
#
#             var marker_564491b1abc9c35578dd6c99728f16c8 = L.marker(
#                 [37.37735165, 126.8712912],
#                 {}
#             ).addTo(map_ef041c31b4cd7a5c732baec37e892d69);
#
#
#             var icon_d410f570a750f503369b2ba26583f11b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&

# %%
map3 = folium.Map(location=[36, 127], zoom_start=7)

from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(map3)

for lat, long in zip(LT.위도, LT.경도):
    folium.Marker([lat, long]).add_to(marker_cluster)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8205280938bfba4338452fac1d7f117c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8205280938bfba4338452fac1d7f117c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8205280938bfba4338452fac1d7f117c = L.map(
#                 &quot;map_8205280938bfba4338452fac1d7f117c&quot;,
#                 {
#                     center: [36.0, 127.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0057e4d9ad51b084995e04ebed762eaa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0057e4d9ad51b084995e04ebed762eaa.addTo(map_8205280938bfba4338452fac1d7f117c);
#
#
#             var marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_00881ee59ce0948c775ee493e3c1d011 = L.marker(
#                 [35.12484689, 129.0743079],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_f841619191e663a879ce7aa8c98cf27c = L.marker(
#                 [35.33123853, 129.2503951],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_c97cbeed7c2c2bd9bd1e02b2f396c88f = L.marker(
#                 [35.86694595, 128.84064],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_0fa7f0bd9998a756494aac3fe2b4bc1b = L.marker(
#                 [37.37735165, 126.8712912],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_0dfec1e5fbba9efce18f87534eb6fa3b = L.marker(
#                 [35.14829091, 128.8702754],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_354763bf3c0ada3b399d2ba3177bf1c1 = L.marker(
#                 [35.16506354, 126.8017562],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_8e762315eddc591714396abc69b6a122 = L.marker(
#                 [35.19771705, 126.7862755],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_122c7b123e8ca6e3655794dcddd279f9 = L.marker(
#                 [35.15437229, 126.7882054],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_15a55f46cd21056555885496fafb570b = L.marker(
#                 [35.1974973, 126.7965799],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_943dc9c92b3ed9aa3c59cc77efe7a300 = L.marker(
#                 [35.19948338, 126.8825576],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_a72b45744a4449057646a0bcd0193530 = L.marker(
#                 [35.19519686, 126.7886524],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_2d6fb77a441b0f348a2fa57d40182489 = L.marker(
#                 [36.4478684, 127.403787],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_55d518edc95ac286591625d00c200d76 = L.marker(
#                 [36.36710653, 127.400822],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_9c9c20493775d53cc06eb38861574a2b = L.marker(
#                 [33.487032, 126.6379809],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_2fb7a48861abd2b6eeb90ea1b3ed81fd = L.marker(
#                 [37.44505753, 126.6273333],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_ddacf9250f0d37866ab7c0ad76dd58ae = L.marker(
#                 [37.56581723, 126.6041478],
#                 {}
#             ).addTo(marker_cluster_a10f4b69e3b4c2f13f6c0ec5b98b1407);
#
#
#             var marker_cb2ecba9f13ae6f106db45cdf5f9cedc = L.marker(
#                 [36.8314344, 126.9690593],
#                 {}
#             )
